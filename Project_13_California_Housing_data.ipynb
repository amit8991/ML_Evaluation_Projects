# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_house = pd.read_csv("california_housing.csv")
print(df_house)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df_house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
df_house.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
df_house.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df_house.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df_house.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df_house['total_bedrooms'].median()
# Out:
# 435.0

# %%
#Replacing null values with median value
df_house['total_bedrooms'].fillna(df_house['total_bedrooms'].median(), inplace=True)

# %%
df_house.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
sns.heatmap(df_house.isnull())

# %%
df_house['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df_house['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
sns.countplot(x='ocean_proximity',data=df_house)
#<1H Ocean has more houses

# %%
df_house.hist(bins=10, figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000206AB7C6C88>,
# ...
#       dtype=object)

# %%
sns.catplot(x="ocean_proximity",y="median_income",kind='bar',data=df_house)

# %%
sns.catplot(x="ocean_proximity",y="median_house_value",kind='bar',data=df_house)

# %%
sns.catplot(x="ocean_proximity",y="population",kind='bar',data=df_house)

# %%
sns.catplot(x="ocean_proximity",y="total_rooms",kind='bar',data=df_house)

# %%
sns.catplot(x="ocean_proximity",y="households",kind='bar',data=df_house)

# %%
sns.catplot(x="ocean_proximity",y="housing_median_age",kind='bar',data=df_house)

# %%
sns.distplot(df_house['median_house_value'])

# %%
sns.distplot(df_house['median_income'])

# %%
plt.scatter(x='median_income',y='median_house_value',data=df_house)
plt.show()

# %%
plt.scatter(x='longitude',y='median_house_value',data=df_house)
plt.show()

# %%
plt.scatter(x='population',y='median_house_value',data=df_house)
plt.show()

# %%
plt.scatter(x='households',y='median_house_value',data=df_house)
plt.show()

# %%
sns.boxplot(x=df_house["median_income"])

# %%
sns.boxplot(x=df_house["median_house_value"])

# %%
sns.boxplot(x=df_house["population"])

# %%
sns.pairplot(df_house)

# %%
#Converting categorical data into Numeric
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_house['ocean_proximity']=le.fit_transform(df_house['ocean_proximity'])

# %%
df_house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0         322         126         8.3252              452600                3
# 1        2401        1138         8.3014              358500                3
# 2         496         177         7.2574              352100                3
# 3         558         219         5.6431              341300                3
# 4         565         259         3.8462              342200                3

# %%
df_house.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069120 -0.066484           -0.319026     0.927058
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# ocean_proximity     -0.289779  0.200974            0.112468    -0.015693
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069120    0.099773    0.055310      -0.015176
# ...

# %%
plt.subplots(figsize=(10,5))
sns.heatmap(df_house.corr(),annot=True)
plt.show()
#House value is positively correlated with housing age,total rooms,median income and negatively correlated with longitude,latitude

# %%
#Check for presence of outliers
from scipy.stats import zscore
z_scr=zscore(df_house)
print(df_house.shape)
df_house_final=df_house.loc[(abs(z_scr)<3).all(axis=1)]
print(df_house_final.shape)
# Out:
# (20640, 10)
# (19746, 10)

# %%
df_house_final.skew()
# Out:
# longitude            -0.288815
# latitude              0.452699
# housing_median_age    0.048371
# total_rooms           1.352462
# total_bedrooms        1.282390
# population            1.238383
# households            1.224020
# median_income         0.787906
# median_house_value    0.981156
# ocean_proximity       1.015165
# dtype: float64

# %%
#Removing skewness
import numpy as np
for index in df_house_final.skew().index:
    if df_house_final.skew().loc[index]>0.5:
        df_house_final[index]=np.sqrt(df_house_final[index])

# %%
df_house_final.skew()
# Out:
# longitude            -0.288815
# latitude              0.452699
# housing_median_age    0.048371
# total_rooms           0.327309
# total_bedrooms        0.328959
# population            0.275434
# households            0.262272
# median_income         0.242173
# median_house_value    0.425821
# ocean_proximity       0.325690
# dtype: float64

# %%
#Seperate the input and output column
df_x=df_house_final.drop(columns=["median_house_value"])
df_y=df_house_final[["median_house_value"]]

# %%
print(df_x.shape)
print(df_y.shape)
# Out:
# (19746, 9)
# (19746, 1)

# %%
df_y
# Out:
#        median_house_value
# 0              672.755528
# 1              598.748695
# 2              593.380148
# 3              584.208867
# 4              584.978632
# ...                   ...
# 20635          279.463772
# 20636          277.668868
# 20637          303.809151
# 20638          291.032644
# 20639          298.998328
#
# [19746 rows x 1 columns]

# %%
#Standard Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
df_x=sc.transform(df_x)

# %%
df_x
# Out:
# array([[-1.32040813,  1.0389946 ,  0.96483669, ..., -1.52865702,
#          2.43862661,  1.26893489],
#        [-1.31541556,  1.02966872, -0.64591639, ...,  2.15334344,
#          2.42855511,  1.26893489],
#        [-1.32540069,  1.02500578,  1.85075089, ..., -1.1885539 ,
#          1.97159743,  1.26893489],
#        ...,
#        [-0.81615912,  1.76175006, -0.96806701, ...,  0.03901233,
#         -1.42062755,  0.30416824],
#        [-0.86608477,  1.76175006, -0.88752936, ..., -0.30893394,
#         -1.26783203,  0.30416824],
#        [-0.82614425,  1.73377243, -1.04860467, ...,  0.40102074,
#         -0.83089527,  0.30416824]])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,df_y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.model_selection import cross_val_score
def model_evaluation(model,df_x,df_y):
    cvs=cross_val_score(model,df_x,df_y,cv=5,scoring="r2")
    print("Mean r2 score : ",cvs.mean())
    print("standard deviation in r2 score for regressor: ",cvs.std())
    print(cvs)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
r_state = maxr2_score(lg,df_x,df_y)
# Out:
# max r2 score corresponding to  48  is  0.6859150707131977

# %%
model_evaluation(lg,df_x,df_y)
# Out:
# Mean r2 score :  0.5978353223710864
# standard deviation in r2 score for regressor:  0.06859476686696671
# [0.59128835 0.48502508 0.59769561 0.61505485 0.70011272]

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_lr=AdaBoostRegressor()
ada_lr1=AdaBoostRegressor(base_estimator=lg,learning_rate=0.1,n_estimators=10)
r_state = maxr2_score(ada_lr1,df_x,df_y)
# Out:
# max r2 score corresponding to  48  is  0.6847143251977512

# %%
model_evaluation(ada_lr1,df_x,df_y)
# Out:
# Mean r2 score :  0.5981720387139312
# standard deviation in r2 score for regressor:  0.06607630449528981
# [0.58397899 0.49385452 0.6009659  0.61106475 0.70099604]

# %% [markdown]
# KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor()
r_state = maxr2_score(knr,df_x,df_y)
# Out:
# max r2 score corresponding to  56  is  0.742428341966357

# %%
model_evaluation(knr,df_x,df_y)
# Out:
# Mean r2 score :  0.5338797220215863
# standard deviation in r2 score for regressor:  0.09780007513936374
# [0.56326532 0.41799192 0.61627358 0.42031904 0.65154875]

# %% [markdown]
# Grid Search CV on KNeighborsRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors
neighbors={"n_neighbors":range(1,30)}
knr = KNeighborsRegressor()
gknr = GridSearchCV(knr,neighbors,cv=10)
gknr.fit(df_x,df_y)
gknr.best_params_
# Out:
# {'n_neighbors': 18}

# %%
knr_cv = KNeighborsRegressor(n_neighbors=18)
r_state = maxr2_score(knr_cv,df_x,df_y)
# Out:
# max r2 score corresponding to  48  is  0.7486519164166798

# %%
model_evaluation(knr_cv,df_x,df_y)
# Out:
# Mean r2 score :  0.5534644692839547
# standard deviation in r2 score for regressor:  0.08925430353176879
# [0.57736305 0.4257472  0.63437982 0.47508509 0.65474719]

# %% [markdown]
# SVR

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = 55,test_size=0.20)
svr = SVR(kernel = "linear")
svr.fit(x_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred_svc=svr.predict(x_test)
print(pred_svc)
# Out:
# [272.49653646 380.87063858 343.37597907 ... 383.79530761 504.97110313
#  476.98201329]

# %%
print("R2 score :",r2_score(y_test,pred_svc))
# Out:
# R2 score : 0.6753266810515053

# %%
print("error:")
print("Mean absolute error:",mean_absolute_error(y_test,pred_svc))
print("Mean squared error:",mean_squared_error(y_test,pred_svc))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred_svc)))
# Out:
# error:
# Mean absolute error: 51.74464197443514
# Mean squared error: 4776.522472032561
# Root mean squared error: 69.11239014845718

# %% [markdown]
# DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state =46,test_size=0.20)
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
pred_dt=dt.predict(x_test)
print(pred_dt)
print("R2 score :",r2_score(y_test,pred_dt))
# Out:
# [386.78159212 443.50873723 304.79501308 ... 467.11882857 547.72255751
#  291.54759474]
# R2 score : 0.6760299265579737

# %%
model_evaluation(dt,df_x,df_y)
# Out:
# Mean r2 score :  0.20865843276988638
# standard deviation in r2 score for regressor:  0.19050062223560854
# [-0.02019401  0.23752936  0.3408879   0.00965502  0.47541389]

# %% [markdown]
# GridSearch CV - DecisionTree regressor

# %%
dt_gs.best_params_

# %%
from sklearn.ensemble import RandomForestRegressor
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state =46,test_size=0.20)
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
pred_rf=dt.predict(x_test)
print(pred_rf)
print("R2 score :",r2_score(y_test,pred_rf))
# Out:
# [386.78159212 443.50873723 304.79501308 ... 467.11882857 547.72255751
#  291.54759474]
# R2 score : 0.6760299265579737

# %%
model_evaluation(rf,df_x,df_y)
# Out:
# Mean r2 score :  0.5169155198114534
# standard deviation in r2 score for regressor:  0.13934025482447898
# [0.49377117 0.53783574 0.65216681 0.26470839 0.6360955 ]

# %%
parameters= {'bootstrap': [True, False],
             'max_depth': [10,40],
             'max_features': ['auto', 'sqrt'],
             'min_samples_leaf': [1,4],
             'min_samples_split': [5,10],
             'n_estimators': [10,50]}

rf_cv = RandomForestRegressor()
rf_random = GridSearchCV(rf, parameters,refit = True, verbose = 3)
rf_random.fit(df_x,df_y)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10, score=0.567, total=   0.8s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10, score=0.642, total=   0.5s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# ...

# %%
best_rf = rf_random.best_estimator_
best_rf
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=40,
#                       max_features='sqrt', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=5,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
pred_rf_cv=best_rf.predict(x_test)
print(pred_rf_cv)
print("R2 score :",r2_score(y_test,pred_rf_cv))
# Out:
# [333.58634644 425.6880369  369.93363123 ... 467.47968463 568.29806013
#  309.42725938]
# R2 score : 0.9948900885633598

# %%
model_evaluation(best_rf,df_x,df_y)
# Out:
# Mean r2 score :  0.6017975893909071
# standard deviation in r2 score for regressor:  0.0705458377540997
# [0.55355252 0.56202584 0.67916523 0.52071691 0.69352745]

# %%
# Selecting Random Forest Regressor Model Grid CV as final , since it has highest R2 score
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state =46,test_size=0.20)
rf_final=RandomForestRegressor()
rf_final.fit(x_train,y_train)
y_pred=rf_final.predict(x_test)

# %%
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# r2_score is:  0.8038222135710487

# %%
print("error:")
print("Mean absolute error:",mean_absolute_error(y_test,y_pred))
print("Mean squared error:",mean_squared_error(y_test,y_pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# error:
# Mean absolute error: 36.66830361318836
# Mean squared error: 2801.3871652723383
# Root mean squared error: 52.92813207805787

# %%
print("Predicted Value:",y_pred)
print("Actual Value:",y_test)
# Out:
# Predicted Value: [366.70216451 479.83424797 405.12442338 ... 470.03935394 517.64639581
#  297.41133732]
# Actual Value:        median_house_value
# 1038           327.414111
# 10394          413.279566
# 15585          366.606056
# 15576          408.289113
# 12816          342.052628
# ...                   ...
# 18392          528.488410
# 10830          473.392015
# 3930           466.583326
# 17248          591.607978
# 18816          304.959014
#
# [3950 rows x 1 columns]

# %%
from sklearn.externals import joblib

#Save the model as pickle in a file
joblib.dump(rf_final,'Model_California_Housing_Data.pkl')
