# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_auto=pd.read_csv("auto.csv")
df_auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df_auto.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df_auto.shape
# Out:
# (398, 9)

# %%
df_auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null int64
# car name        398 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df_auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df_auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car name        0
# dtype: int64

# %%
sns.heatmap(df_auto.isnull())

# %%
#Values counts 
for column in df_auto.columns:
    print("********")
    print(column,":",df_auto[column].unique())
    print(df_auto[column].value_counts())
# Out:
# ********
# mpg : [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 34.2     1
# 38.1     1
# 37.2     1
# 32.1     1
# 32.7     1
# Name: mpg, Length: 129, dtype: int64
# ********
# cylinders : [8 4 6 3 5]
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64
# ...

# %%
df_auto.replace('?',np.NAN,inplace=True)

# %%
df_auto['horsepower'] = df_auto['horsepower'].astype('float')

# %%
df_auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_auto['horsepower'].replace(np.NAN,df_auto['horsepower'].median(),inplace=True)

# %%
df_auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df_auto['car name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
#The car names are not much useful to predict outputs and also its unique,so removing the column
df_auto.drop(['car name'],axis=1,inplace=True)

# %%
df_auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
df_auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# dtype: object

# %%
df_auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.773453 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.841284  0.896017
# displacement -0.804203   0.950721      1.000000    0.895778  0.932824
# horsepower   -0.773453   0.841284      0.895778    1.000000  0.862442
# weight       -0.831741   0.896017      0.932824    0.862442  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.686590 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.413733 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.452096 -0.581024
#
#               acceleration  model_year    origin
# mpg               0.420289    0.579267  0.563450
# cylinders        -0.505419   -0.348746 -0.562543
# displacement     -0.543684   -0.370164 -0.609409
# horsepower       -0.686590   -0.413733 -0.452096
# weight           -0.417457   -0.306564 -0.581024
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df_auto.corr(),annot=True,cmap='BuPu')
plt.show()
#mpg has positive correlation with acceleration,model_year,origin

# %%
df_auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.304020  2970.424623
# std      7.815984    1.701004    104.269838   38.222625   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
sns.countplot(x='model_year',data=df_auto)
#Most cars have model year as 73

# %%
sns.countplot(x='cylinders',data=df_auto)
#Most cars have 4 cylinders

# %%
sns.countplot(x='origin',data=df_auto)
#Region 1 has most vehicles

# %%
plt.figure(figsize=(20,16))
for i,col in enumerate(list(df_auto.columns.values)):
    plt.subplot(5,5,i+1)
    sns.distplot(df_auto[col],color='b',kde=True,label='df_auto')
    plt.grid()
    plt.legend(loc='upper right')
    plt.tight_layout()

# %%
plt.figure(figsize=(25,20))
for i,col in enumerate(list(df_auto.columns.values)):
    plt.subplot(5,5,i+1)
    sns.boxplot(df_auto[col],color="magenta",orient='v')
    plt.grid()
    plt.tight_layout()

# %%
sns.boxplot(x='cylinders',y='mpg',data=df_auto,palette = "rainbow")
plt.show()
#4 cylinders engines have high mpg

# %%
sns.boxplot(x='origin',y='mpg',data=df_auto,palette = "rainbow")
plt.show()
#mpg is higher at origin 3

# %%
sns.boxplot(x='model_year',y='mpg',data=df_auto,palette = "rainbow")
plt.show()
#mpg increases with model_year

# %%
sns.relplot(x="weight", y="mpg", data=df_auto)
#Less weight vehicles have higher mpg

# %%
sns.relplot(x="horsepower", y="mpg", data=df_auto)

# %%
sns.relplot(x="displacement", y="mpg", data=df_auto)

# %%
sns.relplot(x="acceleration", y="mpg", data=df_auto)

# %%
for i, col in enumerate(df_auto.columns):
    plt.figure(i)
    sns.regplot(x="mpg",y=col, data=df_auto)

# %%
sns.pairplot(df_auto)

# %%
#Lets check for outliers
from scipy.stats import zscore
z_score=abs(zscore(df_auto))
print(df_auto.shape)
df_auto_final=df_auto.loc[(z_score<3).all(axis=1)]
print(df_auto_final.shape)
# Out:
# (398, 8)
# (391, 8)

# %%
df_auto_final.skew()
# Out:
# mpg             0.433170
# cylinders       0.552494
# displacement    0.690697
# horsepower      0.989968
# weight          0.542438
# acceleration    0.217097
# model_year      0.004518
# origin          0.911256
# dtype: float64

# %%
for col in df_auto_final.columns:
    if df_auto_final.skew().loc[col]>0.55:
        df_auto_final[col]=np.log1p(df_auto_final[col])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_auto_final.skew()
# Out:
# mpg             0.433170
# cylinders       0.414557
# displacement    0.224197
# horsepower      0.326880
# weight          0.542438
# acceleration    0.217097
# model_year      0.004518
# origin          0.786400
# dtype: float64

# %%
#Separate the dataset into input and output dataset
df_x=df_auto_final.drop(columns=["mpg"])
df_y=df_auto_final[["mpg"]]

# %%
df_x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0     2.197225      5.730100    4.875197    3504          12.0          70
# 1     2.197225      5.860786    5.111988    3693          11.5          70
# 2     2.197225      5.765191    5.017280    3436          11.0          70
# 3     2.197225      5.720312    5.017280    3433          12.0          70
# 4     2.197225      5.713733    4.948760    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 392   1.609438      5.023881    4.510860    2950          17.3          82
# 393   1.609438      4.948760    4.465908    2790          15.6          82
# 395   1.609438      4.912655    4.442651    2295          11.6          82
# 396   1.609438      4.795791    4.382027    2625          18.6          82
# 397   1.609438      4.787492    4.418841    2720          19.4          82
#
#        origin
# 0    0.693147
# 1    0.693147
# 2    0.693147
# ...

# %%
df_y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 392  27.0
# 393  27.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [391 rows x 1 columns]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,df_y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.model_selection import cross_val_score
def model_evaluation(model,df_x,df_y):
    cvs=cross_val_score(model,df_x,df_y,cv=5,scoring="r2")
    print("Mean r2 score : ",cvs.mean())
    print("standard deviation in r2 score for regressor: ",cvs.std())
    print(cvs)

# %% [markdown]
# LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
r_state = maxr2_score(lg,df_x,df_y)
# Out:
# max r2 score corresponding to  73  is  0.8608743688564562

# %%
model_evaluation(lg,df_x,df_y)
# Out:
# Mean r2 score :  0.6056522123385031
# standard deviation in r2 score for regressor:  0.22387666660724878
# [0.47782122 0.75907042 0.82694574 0.73841491 0.22600878]

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_lr=AdaBoostRegressor()
ada_lr1=AdaBoostRegressor(base_estimator=lg,learning_rate=0.1,n_estimators=10)
r_state = maxr2_score(ada_lr1,df_x,df_y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
model_evaluation(ada_lr1,df_x,df_y)
# Out:
# Mean r2 score :  0.6041829716232933
# standard deviation in r2 score for regressor:  0.2039911376727705
# [0.40949806 0.74639516 0.8213163  0.73307761 0.31062772]

# %% [markdown]
# KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor()
r_state = maxr2_score(knr,df_x,df_y)
# Out:
# max r2 score corresponding to  86  is  0.7495115522348436

# %%
model_evaluation(knr,df_x,df_y)
# Out:
# Mean r2 score :  0.3145286849756265
# standard deviation in r2 score for regressor:  0.6364556056476856
# [ 0.56030603  0.4739443   0.75546456  0.72428099 -0.94135246]

# %% [markdown]
# Grid Search CV on KNeighborsRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors
neighbors={"n_neighbors":range(1,30)}
knr = KNeighborsRegressor()
gknr = GridSearchCV(knr,neighbors,cv=10)
gknr.fit(df_x,df_y)
gknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
knr_cv = KNeighborsRegressor(n_neighbors=5)
r_state = maxr2_score(knr_cv,df_x,df_y)
# Out:
# max r2 score corresponding to  86  is  0.7495115522348436

# %%
model_evaluation(knr_cv,df_x,df_y)
# Out:
# Mean r2 score :  0.3145286849756265
# standard deviation in r2 score for regressor:  0.6364556056476856
# [ 0.56030603  0.4739443   0.75546456  0.72428099 -0.94135246]

# %%
ada_knr=AdaBoostRegressor()
ada_knr=AdaBoostRegressor(base_estimator=knr,learning_rate=0.1,n_estimators=10)
r_state = maxr2_score(ada_knr,df_x,df_y)
# Out:
# max r2 score corresponding to  85  is  0.7528088780538073

# %%
model_evaluation(ada_knr,df_x,df_y)
# Out:
# Mean r2 score :  0.2843527636073093
# standard deviation in r2 score for regressor:  0.6029834300690935
# [ 0.47630799  0.34713442  0.76345681  0.716918   -0.88205341]

# %% [markdown]
# SVR

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

svr = SVR(kernel = "linear")
r_state = maxr2_score(svr,df_x,df_y)
# Out:
# max r2 score corresponding to  94  is  0.8495998113524423

# %%
model_evaluation(svr,df_x,df_y)
# Out:
# Mean r2 score :  0.5875037223803903
# standard deviation in r2 score for regressor:  0.2492715523150687
# [0.5847507  0.69095259 0.82181948 0.72736743 0.11262842]

# %% [markdown]
# DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
r_state=maxr2_score(dt,df_x,df_y)
# Out:
# max r2 score corresponding to  94  is  0.878363437234295

# %%
model_evaluation(dt,df_x,df_y)
# Out:
# Mean r2 score :  0.565611130211159
# standard deviation in r2 score for regressor:  0.2442439425362218
# [0.77994608 0.74643163 0.71821766 0.4439301  0.13953019]

# %%
parameters = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }


dt_gs = GridSearchCV(dt, parameters, cv=5)
dt_gs.fit(df_x,df_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 6, 8],
#                          'max_leaf_nodes': [5, 20, 100],
# ...

# %%
dt_gs.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 8,
#  'max_leaf_nodes': 20,
#  'min_samples_leaf': 20,
#  'min_samples_split': 20}

# %%
dt_gs.best_score_
# Out:
# 0.5481003361794293

# %%
dtrg=DecisionTreeRegressor(criterion= 'mse',
 max_depth= 8,
 max_leaf_nodes=20,
 min_samples_leaf= 20,
 min_samples_split= 20)
dtrg.fit(df_x,df_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=8, max_features=None,
#                       max_leaf_nodes=20, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=20,
#                       min_samples_split=20, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
r_state=maxr2_score(rf,df_x,df_y)
# Out:
# max r2 score corresponding to  94  is  0.9274353509170091

# %%
model_evaluation(rf,df_x,df_y)
# Out:
# Mean r2 score :  0.711146928311536
# standard deviation in r2 score for regressor:  0.21066833065539894
# [0.89817625 0.82689796 0.8729492  0.61926391 0.33844732]

# %%
parameters= {'bootstrap': [True, False],
             'max_depth': [10, 20, 30, 40],
             'max_features': ['auto', 'sqrt'],
             'min_samples_leaf': [1, 2, 4],
             'min_samples_split': [2, 5, 10],
             'n_estimators': [10,30,50]}

rf_cv = RandomForestRegressor()
rf_random = GridSearchCV(rf, parameters,refit = True, verbose = 3)
rf_random.fit(df_x,df_y)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10, score=0.704, total=   0.0s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10, score=0.790, total=   0.0s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10, score=0.227, total=   0.0s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# ...

# %%
best_rf = rf_random.best_estimator_

# %%
best_rf
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features='sqrt', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=5,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
r_state=maxr2_score(best_rf,df_x,df_y)
# Out:
# max r2 score corresponding to  94  is  0.9131516364311919

# %%
model_evaluation(best_rf,df_x,df_y)
# Out:
# Mean r2 score :  0.6939845077287067
# standard deviation in r2 score for regressor:  0.28146638293528126
# [0.85543063 0.80143625 0.86729509 0.81250889 0.13325168]

# %%
# Selecting Random Forest Regressor Model as final , since it has highest R2 score 0.92
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state =94,test_size=0.20)
rf_final=RandomForestRegressor()
rf_final.fit(x_train,y_train)
y_pred=rf_final.predict(x_test)

# %%
print("error:")
print("Mean absolute error:",mean_absolute_error(y_test,y_pred))
print("Mean squared error:",mean_squared_error(y_test,y_pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# error:
# Mean absolute error: 1.5259493670886077
# Mean squared error: 4.578659493670885
# Root mean squared error: 2.139780244247265

# %%
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# r2_score is:  0.918984938079306

# %%
print("Predicted Value:",y_pred)
print("Actual Value:",y_test)
# Out:
# Predicted result price: [32.9  36.05 27.6  13.3  25.07 14.5  26.5  12.8  22.8  25.8  14.45 26.45
#  20.4  14.6  21.95 12.9  25.1  18.02 29.88 19.22 20.91 19.38 33.08 14.7
#  17.22 18.39 25.83 19.58 34.28 31.55 34.99 26.89 24.36 20.85 13.3  18.7
#  32.01 20.94 17.71 27.4  13.7  34.17 15.8  35.1  25.4  17.78 32.76 20.73
#  13.8  36.58 19.2  32.76 18.15 14.35 27.7  19.71 18.87 11.5  17.48 31.32
#  21.7  11.5  12.6  30.15 12.2  14.9  13.95 13.9  20.   30.89 14.4  27.44
#  21.52 27.1  30.66 23.4  26.13 15.5  21.01]
# Actual Price:       mpg
# 181  33.0
# 311  32.1
# 151  31.0
# 92   13.0
# 392  27.0
# ..    ...
# 342  30.0
# 150  26.0
# 305  28.4
# 133  16.0
# 76   18.0
#
# [79 rows x 1 columns]

# %%
from sklearn.externals import joblib

#Save the model as pickle in a file
joblib.dump(rf_final,'Model_Auto_MPG_Detection.pkl')
# Out:
# ['Model_Auto_MPG_Detection.pkl']
