# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_excel('Final_Train.xlsx')
df_train
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
df_test = pd.read_excel('Final_Test.xlsx')
df_test
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %%
df_train.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                                   Miscellaneous_Info  Fees
# 0               100% 16 Feedback Kakkanad, Ernakulam   100
# 1              98% 76 Feedback Whitefield, Bangalore   350
# 2                                                NaN   300
# 3  Bannerghatta Road, Bangalore ₹250 Available on...   250
# ...

# %%
df_test.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# 1    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2    70%            KK Nagar, Chennai    Dermatologists
# 3    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4   100%    Kanakpura Road, Bangalore           Dentist
#
#                                   Miscellaneous_Info
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5961 entries, 0 to 5960
# Data columns (total 7 columns):
# Qualification         5961 non-null object
# Experience            5961 non-null object
# Rating                2659 non-null object
# Place                 5936 non-null object
# Profile               5961 non-null object
# Miscellaneous_Info    3341 non-null object
# Fees                  5961 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 326.1+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 6 columns):
# Qualification         1987 non-null object
# Experience            1987 non-null object
# Rating                897 non-null object
# Place                 1981 non-null object
# Profile               1987 non-null object
# Miscellaneous_Info    1153 non-null object
# dtypes: object(6)
# memory usage: 93.3+ KB

# %%
df_train['Data']='Train'
df_test['Data']='Test'
df_test['Fees']=0

# %%
df_fees=pd.concat([df_train,df_test])
df_fees.head()
# Out:
#     Data           Experience  Fees  \
# 0  Train  24 years experience   100
# 1  Train  12 years experience   350
# 2  Train   9 years experience   300
# 3  Train  12 years experience   250
# 4  Train  20 years experience   250
#
#                                   Miscellaneous_Info  \
# 0               100% 16 Feedback Kakkanad, Ernakulam
# 1              98% 76 Feedback Whitefield, Bangalore
# 2                                                NaN
# 3  Bannerghatta Road, Bangalore ₹250 Available on...
# 4              100% 4 Feedback Keelkattalai, Chennai
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                     Qualification Rating
# 0           BHMS, MD - Homeopathy   100%
# ...

# %%
df_fees['Data'].value_counts()
# Out:
# Train    5961
# Test     1987
# Name: Data, dtype: int64

# %%
df_fees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7948 entries, 0 to 1986
# Data columns (total 8 columns):
# Data                  7948 non-null object
# Experience            7948 non-null object
# Fees                  7948 non-null int64
# Miscellaneous_Info    4494 non-null object
# Place                 7917 non-null object
# Profile               7948 non-null object
# Qualification         7948 non-null object
# Rating                3556 non-null object
# dtypes: int64(1), object(7)
# memory usage: 558.8+ KB

# %%
df_fees.isnull().sum()
#Misc info & rating have most null values
# Out:
# Data                     0
# Experience               0
# Fees                     0
# Miscellaneous_Info    3454
# Place                   31
# Profile                  0
# Qualification            0
# Rating                4392
# dtype: int64

# %%
#Converting Experience column into numerical
df_fees['Experience']=df_fees['Experience'].str.split(' ').str[0]
df_fees['Experience']=df_fees['Experience'].astype(int)

# %%
df_fees['Experience'].dtypes
# Out:
# dtype('int32')

# %%
df_fees
# Out:
#        Data  Experience  Fees  \
# 0     Train          24   100
# 1     Train          12   350
# 2     Train           9   300
# 3     Train          12   250
# 4     Train          20   250
# ...     ...         ...   ...
# 1982   Test          10     0
# 1983   Test           4     0
# 1984   Test           9     0
# 1985   Test          12     0
# 1986   Test           8     0
#
#                                      Miscellaneous_Info  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam
# 1                 98% 76 Feedback Whitefield, Bangalore
# 2                                                   NaN
# 3     Bannerghatta Road, Bangalore ₹250 Available on...
# 4                 100% 4 Feedback Keelkattalai, Chennai
# ...                                                 ...
# 1982                                                NaN
# 1983                                                NaN
# 1984                                                NaN
# ...

# %%
#Place column , splitting it into Place & City
df_fees['Place'].fillna(df_fees['Place'].mode()[0], inplace=True)
df_fees["Place"] = df_fees["Place"].str.split(",")
df_fees["City"] = df_fees["Place"].str[-1]
df_fees["Place"] = df_fees["Place"].str[0]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_fees['City']=le.fit_transform(df_fees['City'])
df_fees['Place']=le.fit_transform(df_fees['Place'])

# %%
df_fees.head()
# Out:
#     Data  Experience  Fees                                 Miscellaneous_Info  \
# 0  Train          24   100               100% 16 Feedback Kakkanad, Ernakulam
# 1  Train          12   350              98% 76 Feedback Whitefield, Bangalore
# 2  Train           9   300                                                NaN
# 3  Train          12   250  Bannerghatta Road, Bangalore ₹250 Available on...
# 4  Train          20   250              100% 4 Feedback Keelkattalai, Chennai
#
#    Place         Profile                   Qualification Rating  City
# 0    324       Homeopath           BHMS, MD - Homeopathy   100%     4
# 1    925        Ayurveda    BAMS, MD - Ayurveda Medicine    98%     0
# 2    494  ENT Specialist  MBBS, MS - Otorhinolaryngology    NaN     0
# 3     74        Ayurveda             BSc - Zoology, BAMS    NaN     0
# 4    367        Ayurveda                            BAMS   100%     1

# %%
df_fees['Profile'].unique()
# Out:
# array(['Homeopath', 'Ayurveda', 'ENT Specialist', 'Dentist',
#        'General Medicine', 'Dermatologists'], dtype=object)

# %%
df_fees['Profile'].value_counts()
# Out:
# Dentist             1838
# General Medicine    1617
# Dermatologists      1373
# Homeopath           1120
# Ayurveda            1037
# ENT Specialist       963
# Name: Profile, dtype: int64

# %%
#Qualification
df_fees['Qualification'].unique()
# Out:
# array(['BHMS, MD - Homeopathy', 'BAMS, MD - Ayurveda Medicine',
#        'MBBS, MS - Otorhinolaryngology', ...,
#        'MD - Medicine, Post Graduate Diploma in Diabetology (PGDD), MBBS, FRCP - Internal Medicine',
#        'MBBS, MS - General Surgery, FAIS, FIAGES',
#        'MBBS, MD / MS - Obstetrics & Gynaecology'], dtype=object)

# %%
# Rating Column and Miscellaneous_Info has maximum no of Null so deleting these columns
df_fees.drop('Rating',axis=1,inplace=True)

# %%
df_fees.drop('Miscellaneous_Info',axis=1,inplace=True)

# %%
df_fees
# Out:
#        Data  Experience  Fees  Place           Profile  \
# 0     Train          24   100    324         Homeopath
# 1     Train          12   350    925          Ayurveda
# 2     Train           9   300    494    ENT Specialist
# 3     Train          12   250     74          Ayurveda
# 4     Train          20   250    367          Ayurveda
# ...     ...         ...   ...    ...               ...
# 1982   Test          10     0     76          Ayurveda
# 1983   Test           4     0    135    Dermatologists
# 1984   Test           9     0    658  General Medicine
# 1985   Test          12     0     34           Dentist
# 1986   Test           8     0    607    Dermatologists
#
#                                        Qualification  City
# 0                              BHMS, MD - Homeopathy     4
# 1                       BAMS, MD - Ayurveda Medicine     0
# 2                     MBBS, MS - Otorhinolaryngology     0
# 3                                BSc - Zoology, BAMS     0
# ...

# %%
df_fees.isnull().sum()
# Out:
# Data             0
# Experience       0
# Fees             0
# Place            0
# Profile          0
# Qualification    0
# City             0
# dtype: int64

# %%
df_fees['Qualification'].value_counts()
# Out:
# BDS                                                                                     632
# BHMS                                                                                    627
# BAMS                                                                                    624
# MBBS                                                                                    441
# MBBS, MS - ENT                                                                          280
#                                                                                        ...
# MBBS, DNB, Master of Hospital Administration                                              1
# MD - Dermatology, Diploma in Dermatology, MBBS                                            1
# MRCS (UK), MS - ENT, MBBS                                                                 1
# MBBS, Fellowship in Diabetology, Certificate Course in Gestational Diabetes Mellitus      1
# ...

# %%
#df_fees['Qual_1']=df_fees['Qualification'].str.split(' ').str[0]

# %%
df_fees
# Out:
#        Data  Experience  Fees  Place           Profile  \
# 0     Train          24   100    324         Homeopath
# 1     Train          12   350    925          Ayurveda
# 2     Train           9   300    494    ENT Specialist
# 3     Train          12   250     74          Ayurveda
# 4     Train          20   250    367          Ayurveda
# ...     ...         ...   ...    ...               ...
# 1982   Test          10     0     76          Ayurveda
# 1983   Test           4     0    135    Dermatologists
# 1984   Test           9     0    658  General Medicine
# 1985   Test          12     0     34           Dentist
# 1986   Test           8     0    607    Dermatologists
#
#                                        Qualification  City
# 0                              BHMS, MD - Homeopathy     4
# 1                       BAMS, MD - Ayurveda Medicine     0
# 2                     MBBS, MS - Otorhinolaryngology     0
# 3                                BSc - Zoology, BAMS     0
# ...

# %%
def qualification_change(x):
    if ',' not in x:
        return x.split(' ')[0]
    else:
        return x.split(',')[0]

# %%
df_fees['Qualification']=df_fees['Qualification'].apply(qualification_change)

# %%
def qualification_2(x):
    if '-' in x:
        return x.split('-')[0]
    else:
        return x

# %%
df_fees['Qualification']=df_fees['Qualification'].apply(qualification_2)
df_fees
# Out:
#        Data  Experience  Fees  Place           Profile Qualification  City
# 0     Train          24   100    324         Homeopath          BHMS     4
# 1     Train          12   350    925          Ayurveda          BAMS     0
# 2     Train           9   300    494    ENT Specialist          MBBS     0
# 3     Train          12   250     74          Ayurveda          BSc      0
# 4     Train          20   250    367          Ayurveda          BAMS     1
# ...     ...         ...   ...    ...               ...           ...   ...
# 1982   Test          10     0     76          Ayurveda          BAMS     0
# 1983   Test           4     0    135    Dermatologists           MD      1
# 1984   Test           9     0    658  General Medicine          MBBS     1
# 1985   Test          12     0     34           Dentist           BDS     0
# 1986   Test           8     0    607    Dermatologists          MBBS     1
#
# [7948 rows x 7 columns]

# %%
df_fees['Qualification'].value_counts()
# Out:
# MBBS                                                                   3313
# BDS                                                                    1579
# BAMS                                                                    939
# BHMS                                                                    938
# MD                                                                      338
#                                                                        ...
# Cochlear Implant Surgery                                                  1
# Diploma in Family Medicine (DFM)                                          1
# FNB                                                                       1
# BUMS                                                                      1
# Post Graduate Diploma in Diabetology (PGDD)(Madras Medical College)       1
# Name: Qualification, Length: 120, dtype: int64

# %%
df_fees.isnull().sum()
# Out:
# Data             0
# Experience       0
# Fees             0
# Place            0
# Profile          0
# Qualification    0
# City             0
# dtype: int64

# %%
df_fees['Fees'].hist()

# %%
ax1=sns.countplot(x='Profile',data=df_fees)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Homeopath'),
#  Text(0, 0, 'Ayurveda'),
#  Text(0, 0, 'ENT Specialist'),
#  Text(0, 0, 'Dentist'),
#  Text(0, 0, 'General Medicine'),
#  Text(0, 0, 'Dermatologists')]

# %%
ax1=sns.barplot(x='Profile',y='Fees',data=df_fees)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, horizontalalignment='right')
#ENT Specialist & Dermotolgists have higher fees,Ayurveda & Dentist have lower fees
# Out:
# [Text(0, 0, 'Homeopath'),
#  Text(0, 0, 'Ayurveda'),
#  Text(0, 0, 'ENT Specialist'),
#  Text(0, 0, 'Dentist'),
#  Text(0, 0, 'General Medicine'),
#  Text(0, 0, 'Dermatologists')]

# %%
ax1=sns.barplot(x='Profile',y='Experience',data=df_fees)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, horizontalalignment='right')
#General Medicine doctors have higher experience
# Out:
# [Text(0, 0, 'Homeopath'),
#  Text(0, 0, 'Ayurveda'),
#  Text(0, 0, 'ENT Specialist'),
#  Text(0, 0, 'Dentist'),
#  Text(0, 0, 'General Medicine'),
#  Text(0, 0, 'Dermatologists')]

# %%
df_fees['City'].value_counts()
# Out:
# 0    1678
# 6    1639
# 3    1602
# 5    1284
# 1    1142
# 2     298
# 4     201
# 7     103
# 8       1
# Name: City, dtype: int64

# %%
ax1=sns.barplot(x='City',y='Fees',data=df_fees)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, horizontalalignment='right')
#Fees are higher in Delhi
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8')]

# %%
sns.catplot(x="Fees",y="Profile",kind='box',data=df_fees)

# %%
sns.catplot(x="Experience",y="Profile",kind='violin',data=df_fees)

# %%
df_fees.hist(column='Experience', bins=20)
#Experience is high between 8-15
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C6F03FA948>]],
#       dtype=object)

# %%
sns.scatterplot(x="Fees", y="Experience", data=df_fees)
#Experience has no reltionship with Fees

# %%
df_fees['City'].value_counts().plot(kind='barh')

# %%
df_fees['Place'].value_counts()
# Out:
# 29     128
# 244     97
# 176     94
# 73      85
# 531     81
#       ...
# 118      1
# 130      1
# 134      1
# 138      1
# 0        1
# Name: Place, Length: 937, dtype: int64

# %%
df_fees['Place'].value_counts()[:10].plot(kind='barh')

# %%
ax1=sns.boxplot(x="City", y="Fees", data=df_fees)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8')]

# %%
df_fees['City'].isnull().sum()
# Out:
# 0

# %%
#Converting categorical data into Numeric
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_fees['Profile']=le.fit_transform(df_fees['Profile'])
df_fees['Qualification']=le.fit_transform(df_fees['Qualification'])

# %%
df_fees.dtypes
# Out:
# Data             object
# Experience        int32
# Fees              int64
# Place             int32
# Profile           int32
# Qualification     int32
# City              int32
# dtype: object

# %%
df_fees.corr()
# Out:
#                Experience      Fees     Place   Profile  Qualification  \
# Experience       1.000000 -0.012432  0.026170  0.190219       0.231999
# Fees            -0.012432  1.000000 -0.033669  0.086961       0.159159
# Place            0.026170 -0.033669  1.000000  0.014901       0.001444
# Profile          0.190219  0.086961  0.014901  1.000000       0.339170
# Qualification    0.231999  0.159159  0.001444  0.339170       1.000000
# City             0.016137 -0.017092 -0.099832 -0.003326      -0.035805
#
#                    City
# Experience     0.016137
# Fees          -0.017092
# Place         -0.099832
# Profile       -0.003326
# Qualification -0.035805
# City           1.000000

# %%
sns.heatmap(df_fees.corr(),annot=True)

# %%
sns.distplot(df_fees['Fees'])

# %%
sns.pairplot(df_fees)

# %%
df_train_final=df_fees.loc[df_fees['Data']=='Train']
df_test_final=df_fees.loc[df_fees['Data']=='Test']

# %%
df_train_final.drop(['Data'],axis=1,inplace=True)
df_test_final.drop(['Data'],axis=1,inplace=True)

# %%
df_train_final
# Out:
#       Experience  Fees  Place  Profile  Qualification  City
# 0             24   100    324        5              8     4
# 1             12   350    925        0              5     0
# 2              9   300    494        3             87     0
# 3             12   250     74        0             13     0
# 4             20   250    367        0              5     1
# ...          ...   ...    ...      ...            ...   ...
# 5956          19   300     76        3             87     0
# 5957          33   100    583        4             87     1
# 5958          41   600    233        4             87     3
# 5959          15   100    908        4             87     6
# 5960          17   200    650        1              6     3
#
# [5961 rows x 6 columns]

# %%
#Check for presence of outliers
from scipy.stats import zscore
z_scr=zscore(df_train_final)
print(df_train_final.shape)
df_train_final=df_train_final.loc[(abs(z_scr)<3).all(axis=1)]
print(df_train_final.shape)
# Out:
# (5961, 6)
# (5903, 6)

# %%
df_train_final.skew()
# Out:
# Experience       0.897661
# Fees             0.710445
# Place            0.105715
# Profile          0.121336
# Qualification   -0.115860
# City            -0.010740
# dtype: float64

# %%
#Removing skewness
import numpy as np
for index in df_train_final.skew().index:
    if df_train_final.skew().loc[index]>0.5:
        df_train_final[index]=np.sqrt(df_train_final[index])

# %%
df_train_final.skew()
# Out:
# Experience       0.023642
# Fees             0.221493
# Place            0.105715
# Profile          0.121336
# Qualification   -0.115860
# City            -0.010740
# dtype: float64

# %%
#Seperate the input and output column
df_x=df_train_final.drop(columns=["Fees"])
df_y=df_train_final[["Fees"]]

# %%
print(df_x.shape,df_y.shape)
# Out:
# (5903, 5) (5903, 1)

# %%
df_x
# Out:
#       Experience  Place  Profile  Qualification  City
# 0       4.898979    324        5              8     4
# 1       3.464102    925        0              5     0
# 2       3.000000    494        3             87     0
# 3       3.464102     74        0             13     0
# 4       4.472136    367        0              5     1
# ...          ...    ...      ...            ...   ...
# 5956    4.358899     76        3             87     0
# 5957    5.744563    583        4             87     1
# 5958    6.403124    233        4             87     3
# 5959    3.872983    908        4             87     6
# 5960    4.123106    650        1              6     3
#
# [5903 rows x 5 columns]

# %%
df_y
# Out:
#            Fees
# 0     10.000000
# 1     18.708287
# 2     17.320508
# 3     15.811388
# 4     15.811388
# ...         ...
# 5956  17.320508
# 5957  10.000000
# 5958  24.494897
# 5959  10.000000
# 5960  14.142136
#
# [5903 rows x 1 columns]

# %%
#Standard Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
df_x=sc.transform(df_x)

# %%
df_x
# Out:
# array([[ 0.74416866, -0.43481593,  1.5477261 , -1.03711387,  0.4053466 ],
#        [-0.33380959,  1.7285363 , -1.46613785, -1.11147055, -1.33389453],
#        [-0.68247442,  0.17711399,  0.34218052,  0.92094546, -1.33389453],
#        ...,
#        [ 1.87418493, -0.76237841,  0.94495331,  0.92094546, -0.02946368],
#        [-0.02662971,  1.66734331,  0.94495331,  0.92094546,  1.27496717],
#        [ 0.16127923,  0.73864967, -0.86336506, -1.08668499, -0.02946368]])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,df_y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)

# %%
from sklearn.model_selection import cross_val_score
def model_evaluation(model,df_x,df_y):
    cvs=cross_val_score(model,df_x,df_y,cv=5,scoring="r2")
    print("Mean r2 score : ",cvs.mean())
    print("standard deviation in r2 score for regressor: ",cvs.std())
    print(cvs)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
r_state = maxr2_score(lg,df_x,df_y)
# Out:
# max r2 score corresponding to  47  is  0.10231316426248693

# %%
model_evaluation(lg,df_x,df_y)
# Out:
# Mean r2 score :  0.06813899763229651
# standard deviation in r2 score for regressor:  0.008107436448507453
# [0.06019451 0.06525873 0.06304656 0.06886466 0.08333052]

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = 47,test_size=0.20)
lg_pred=lg.predict(x_test)
print("Predicted result price:",lg_pred)
print("actual price",y_test)
# Out:
# Predicted result price: [[14.37899598]
#  [14.85987512]
#  [18.32428048]
#  ...
#  [14.60765528]
#  [17.48769569]
#  [14.62562568]]
# actual price            Fees
# 4976  10.000000
# 1597  22.360680
# 815   12.247449
# 4233  14.142136
# 2241  28.284271
# ...         ...
# 4702  10.000000
# 1274  10.000000
# 2727  17.320508
# 2652  18.708287
# 4610  17.320508
#
# [1181 rows x 1 columns]

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,lg_pred))
print('Mean sqaured error:',mean_squared_error(y_test,lg_pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,lg_pred)))
# Out:
# error:
# Mean absolute error: 4.240586847111392
# Mean sqaured error: 26.19824305341864
# Root mean squared error: 5.118421929991571

# %%
from sklearn.metrics import mean_squared_log_error
print("r2_score is: ",r2_score(y_test,lg_pred))
rmsle_lg_scr=np.sqrt(mean_squared_log_error(y_test,lg_pred))
print("RMSLE score :",rmsle_lg_scr)
# Out:
# r2_score is:  0.10740464510337855
# RMSLE score : 0.3051211407062957

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(df_x,df_y) 
dt.score(x_train,y_train)
pred_dt=dt.predict(x_test)

# %%
print("r2_score is: ",r2_score(y_test,pred_dt))
rmsle_dt_scr=np.sqrt(mean_squared_log_error(y_test,pred_dt))
print("RMSLE score :",rmsle_dt_scr)
# Out:
# r2_score is:  0.9706090858597396
# RMSLE score : 0.05647588290574047

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_dt))
print('Mean sqaured error:',mean_squared_error(y_test,pred_dt))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_dt)))
# Out:
# error:
# Mean absolute error: 0.1996198483450662
# Mean sqaured error: 0.8626420785013836
# Root mean squared error: 0.9287852703942842

# %%
print("Predicted result price:",pred_dt)
print("actual price",y_test)
# Out:
# Predicted result price: [18.22875656 22.36067977 12.24744871 ... 17.32050808 18.70828693
#  17.32050808]
# actual price            Fees
# 4976  10.000000
# 1597  22.360680
# 815   12.247449
# 4233  14.142136
# 2241  28.284271
# ...         ...
# 4702  10.000000
# 1274  10.000000
# 2727  17.320508
# 2652  18.708287
# 4610  17.320508
#
# [1181 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
parameters = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }


dt_gs = GridSearchCV(dt, parameters, cv=5)
dt_gs.fit(df_x,df_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 6, 8],
#                          'max_leaf_nodes': [5, 20, 100],
# ...

# %%
dt_gs.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 6,
#  'max_leaf_nodes': 100,
#  'min_samples_leaf': 40,
#  'min_samples_split': 40}

# %%
dtrg=DecisionTreeRegressor(criterion= 'mse',
 max_depth= 6,
 max_leaf_nodes=100,
 min_samples_leaf= 40,
 min_samples_split= 40)
dtrg.fit(df_x,df_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=6, max_features=None,
#                       max_leaf_nodes=100, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=40,
#                       min_samples_split=40, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
dtrg.score(x_train,y_train)
pred_dt_cv=dtrg.predict(x_test)
print("r2_score is: ",r2_score(y_test,pred_dt_cv))
rmsle_dtcv_scr=np.sqrt(mean_squared_log_error(y_test,pred_dt_cv))
print("RMSLE score :",rmsle_dtcv_scr)
# Out:
# r2_score is:  0.21570753830344014
# RMSLE score : 0.2839230246303095

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_dt_cv))
print('Mean sqaured error:',mean_squared_error(y_test,pred_dt_cv))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_dt_cv)))
# Out:
# error:
# Mean absolute error: 3.9254067782401534
# Mean sqaured error: 23.019484051505316
# Root mean squared error: 4.797862446080058

# %%
#KNN regressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors
neighbors={"n_neighbors":range(1,30)}
knr = KNeighborsRegressor()
gknr = GridSearchCV(knr,neighbors,cv=10)
gknr.fit(df_x,df_y)
gknr.best_params_
# Out:
# {'n_neighbors': 26}

# %%
knr_cv = KNeighborsRegressor(n_neighbors=26)
r_state = maxr2_score(knr_cv,df_x,df_y)
# Out:
# max r2 score corresponding to  72  is  0.17821487526674729

# %%
knr_pred=gknr.predict(x_test)
print("Predicted result price:",knr_pred)
print("actual price",y_test)
# Out:
# Predicted result price: [[12.29144425]
#  [17.31654386]
#  [15.3683286 ]
#  ...
#  [16.6708786 ]
#  [18.73508496]
#  [14.36798028]]
# actual price            Fees
# 4976  10.000000
# 1597  22.360680
# 815   12.247449
# 4233  14.142136
# 2241  28.284271
# ...         ...
# 4702  10.000000
# 1274  10.000000
# 2727  17.320508
# 2652  18.708287
# 4610  17.320508
#
# [1181 rows x 1 columns]

# %%
print("r2_score is: ",r2_score(y_test,knr_pred))
rmsle_knrcv_scr=np.sqrt(mean_squared_log_error(y_test,knr_pred))
print("RMSLE score :",rmsle_knrcv_scr)
# Out:
# r2_score is:  0.23005465744094522
# RMSLE score : 0.28195678323733847

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,knr_pred))
print('Mean sqaured error:',mean_squared_error(y_test,knr_pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,knr_pred)))
# Out:
# error:
# Mean absolute error: 3.878511485024876
# Mean sqaured error: 22.598386952782185
# Root mean squared error: 4.753776073058362

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
r_state = maxr2_score(rfr,df_x,df_y)
# Out:
# max r2 score corresponding to  57  is  0.17824419890886112

# %%
rfr_pred=rfr.predict(x_test)
print("r2_score is: ",r2_score(y_test,rfr_pred))
rmsle_rfr_scr=np.sqrt(mean_squared_log_error(y_test,rfr_pred))
print("RMSLE score :",rmsle_rfr_scr)
# Out:
# r2_score is:  0.6885922761790914
# RMSLE score : 0.18147001348417346

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,rfr_pred))
print('Mean sqaured error:',mean_squared_error(y_test,rfr_pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,rfr_pred)))
# Out:
# error:
# Mean absolute error: 2.003825157112944
# Mean sqaured error: 9.140015341349061
# Root mean squared error: 3.0232458287987534

# %%
parameters= {'bootstrap': [True, False],
             'max_depth': [10, 20, 30, 40],
             'max_features': ['auto', 'sqrt'],
             'min_samples_leaf': [1, 2, 4],
             'min_samples_split': [2, 5, 10],
             'n_estimators': [10,30,50]}

rf_cv = RandomForestRegressor()
rf_random = GridSearchCV(rfr, parameters,refit = True, verbose = 3)
rf_random.fit(df_x,df_y)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10, score=0.158, total=   0.1s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV]  bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10, score=0.194, total=   0.1s
# [CV] bootstrap=True, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# ...

# %%
best_rf = rf_random.best_estimator_

# %%
best_rf
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
r_state=maxr2_score(best_rf,df_x,df_y)
# Out:
# max r2 score corresponding to  84  is  0.24437147673493065

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state =84,test_size=0.20)
rf_final=RandomForestRegressor()
rf_final.fit(x_train,y_train)
rf_pred=rf_final.predict(x_test)

# %%
print("error:")
print("Mean absolute error:",mean_absolute_error(y_test,rf_pred))
print("Mean squared error:",mean_squared_error(y_test,rf_pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,rf_pred)))
# Out:
# error:
# Mean absolute error: 3.852795660610586
# Mean squared error: 24.376331027125254
# Root mean squared error: 4.937239211049557

# %%
print("r2_score is: ",r2_score(y_test,rf_pred))
rmsle_rfcv_scr=np.sqrt(mean_squared_log_error(y_test,rf_pred))
print("RMSLE score :",rmsle_rfcv_scr)
# Out:
# r2_score is:  0.15933771403815566
# RMSLE score : 0.2951827594638066

# %%
print("Predicted Value:",rf_pred)
print("Actual Value:",y_test)
# Out:
# Predicted Value: [11.14626437 18.         20.41176026 ... 21.45769893 11.94520153
#  12.48528137]
# Actual Value:            Fees
# 3962  28.284271
# 720   17.320508
# 2345  20.000000
# 2117  20.000000
# 1333  14.142136
# ...         ...
# 4482  14.142136
# 4542  14.142136
# 4794  28.284271
# 3578  15.811388
# 5139  12.247449
#
# [1181 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
LR=LinearRegression()
LA=Lasso()
RI=Ridge()
EN=ElasticNet()
KNR=KNeighborsRegressor()
SV=SVR()
DTR=DecisionTreeRegressor()
ABR=AdaBoostRegressor()
RFR=RandomForestRegressor()
GBR=GradientBoostingRegressor()
XGR=XGBRegressor()

# %%
models=[]
models.append(('LinearRegression',LR))
models.append(('Lasso',LA))
models.append(('Ridge',RI))
models.append(('ElasticNet',EN))
models.append(('DecisionTreeRegressor',DTR))
models.append(('SVR',SV))
models.append(('KNeighborsRegressor',KNR))
models.append(('AdaBoostRegressor',ABR))
models.append(('RandomForestRegressor',RFR))
models.append(('GradientBoostingRegressor',GBR))
models.append(('XGBRegressor',XGR))

# %%
Model=[]
R2_score=[]
cvs=[]
MSE=[]
rmse=[]
rmlse=[]
for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2=r2_score(y_test,pre)
    print('R2_score = ',r2)
    R2_score.append(r2)
    mse=mean_squared_error(y_test,pre)
    print("Mean_Squared_Error =",mse)
    MSE.append(round(mse,3))
    b=np.sqrt(mse)
    print('RMSE= ',b)
    rmse.append(b)
    score= cross_val_score(model,df_x,df_y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score = ',score)
    cvs.append(score)
    rmsle_scr=np.sqrt(mean_squared_log_error(y_test,pre))
    print("RMSLE score :",rmsle_scr)
    rmlse.append(rmsle_scr)
    print('\n')
# Out:
# ********************************* LinearRegression *********************************
#
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2_score =  0.07027161423862249
# Mean_Squared_Error = 26.95894329398141
# RMSE=  5.192200236314217
# Cross_Val_Score =  0.06816734309539105
# RMSLE score : 0.31289169859863214
#
#
# ********************************* Lasso *********************************
#
#  Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# R2_score =  0.025034392431195984
# Mean_Squared_Error = 28.27066800429554
# RMSE=  5.317016833177749
# Cross_Val_Score =  0.02332494464312911
# RMSLE score : 0.3210582831231347
#
#
# ********************************* Ridge *********************************
#
#  Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
# ...

# %%
result = pd.DataFrame({'Model': Model, 'R2_score': R2_score ,'Mean_Squared_Error' :MSE,'RMSE' : rmse ,'Cross_val_score':cvs,'RMLSE':rmlse})
result
# Out:
#                         Model  R2_score  Mean_Squared_Error      RMSE  \
# 0            LinearRegression  0.070272              26.959  5.192200
# 1                       Lasso  0.025034              28.271  5.317017
# 2                       Ridge  0.070270              26.959  5.192203
# 3                  ElasticNet  0.042428              27.766  5.269374
# 4       DecisionTreeRegressor -0.412651              40.962  6.400161
# 5                         SVR  0.125756              25.350  5.034887
# 6         KNeighborsRegressor  0.083799              26.567  5.154290
# 7           AdaBoostRegressor  0.131499              25.184  5.018322
# 8       RandomForestRegressor  0.154566              24.515  4.951232
# 9   GradientBoostingRegressor  0.211129              22.875  4.782737
# 10               XGBRegressor  0.212175              22.844  4.779563
#
#     Cross_val_score     RMLSE
# 0          0.068167  0.312892
# 1          0.023325  0.321058
# 2          0.068168  0.312892
# ...

# %%
#Selecting XGBRegressor as final model,because of low RMSE score
XGR=XGBRegressor()
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,test_size=0.20)
XGR.fit(x_train,y_train)
xgr_pred=rf_final.predict(x_test)
# Out:
# [10:34:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print("r2_score is: ",r2_score(y_test,xgr_pred))
rmsle_xgb_scr=np.sqrt(mean_squared_log_error(y_test,xgr_pred))
print("RMSLE score :",rmsle_xgb_scr)
# Out:
# r2_score is:  0.7236589548632463
# RMSLE score : 0.17667071496220682

# %%
print("error:")
print("Mean absolute error:",mean_absolute_error(y_test,xgr_pred))
print("Mean squared error:",mean_squared_error(y_test,xgr_pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,xgr_pred)))
# Out:
# error:
# Mean absolute error: 1.9402782164212053
# Mean squared error: 8.079813278985803
# Root mean squared error: 2.842501236408843

# %%
print("Predicted Value:",xgr_pred)
print("Actual Value:",y_test)
# Out:
# Predicted Value: [20.23606798 20.31482129 14.56719601 ... 17.38765724 18.22474487
#  17.90628969]
# Actual Value:            Fees
# 5013  20.000000
# 196   21.213203
# 460   10.000000
# 1987  28.284271
# 4601  22.360680
# ...         ...
# 3199  10.000000
# 381   12.247449
# 221   17.320508
# 3058  20.000000
# 480   15.811388
#
# [1181 rows x 1 columns]

# %%
from sklearn.externals import joblib

joblib.dump(XGR,'Model_Doctor_Fees_Prediction.pkl')
# Out:
# ['Model_Doctor_Fees_Prediction.pkl']
