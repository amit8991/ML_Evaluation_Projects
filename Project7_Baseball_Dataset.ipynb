# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_baseball = pd.read_csv("baseball.csv")
print(df_baseball)
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df_baseball.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df_baseball.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df_baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# W      30 non-null int64
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df_baseball.shape
# Out:
# (30, 17)

# %%
df_baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df_baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df_baseball.isnull())

# %%
df_baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df_baseball.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_baseball.corr(),annot=True)
plt.show()
#Win has strong negative correlation with RA,ER,ERA and positive correleation with 2B,SHO,SV

# %%
df_baseball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# #Comparing wins with other variables

# %%
sns.regplot(x="W", y="R", data=df_baseball);

# %%
sns.regplot(x="W", y="AB", data=df_baseball);

# %%
sns.regplot(x="W", y="H", data=df_baseball);

# %%
for i, col in enumerate(df_baseball.columns):
    plt.figure(i)
    sns.regplot(x="W",y=col, data=df_baseball)

#SHO,R,2B,HR,BB,SV have linear relationship with wins

# %%
plt.figure(figsize=(15,8))
for i,col in enumerate(list(df_baseball.columns.values)):
    plt.subplot(5,5,i+1)
    df_baseball.boxplot(col)
    plt.grid()
    plt.show()

# %%
sns.distplot(df_baseball['W'], rug=True);

# %%
sns.pairplot(df_baseball)
plt.show()

# %%
#Check for outliers
from scipy.stats import zscore
z_score=abs(zscore(df_baseball))
print(df_baseball.shape)
df_baseball=df_baseball.loc[(z_score<3).all(axis=1)]
print(df_baseball.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
#Check Skewness
df_baseball.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
import numpy as np
for col in df_baseball.columns:
    if df_baseball.skew().loc[col]>0.55:
        df_baseball[col]=np.log1p(df_baseball[col])

# %%
#Again Check for Skewness
df_baseball.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %%
#Separate the dataset into input and output dataset
df_x=df_baseball.drop(columns=["W"])
df_y=df_baseball[["W"]]

# %%
df_x.shape
# Out:
# (29, 16)

# %%
df_y.shape
# Out:
# (29, 1)

# %%
df_x
# Out:
#       R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   724  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1   696  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2   669  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3   622  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4   689  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
# 6   764  5567  7.242798  272  19  212  554  1227   63  698  652  4.03
# 7   713  5485  7.223296  246  20  217  418  1331   44  693  646  4.05
# 8   644  5485  7.232733  278  32  167  436  1310   87  642  604  3.74
# 9   748  5640  7.310550  294  33  161  478  1148   71  753  694  4.31
# 10  751  5511  7.258412  279  32  172  503  1233  101  733  680  4.24
# 11  729  5459  7.218177  278  26  230  486  1392  121  618  572  3.57
# 12  661  5417  7.194437  243  21  176  435  1150   52  675  630  3.94
# ...

# %%
df_y
# Out:
#       W
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# 6    87
# 7    81
# 8    80
# 9    78
# 10   88
# 11   86
# 12   85
# 13   76
# 14   68
# 15  100
# 16   98
# 17   97
# 18   68
# 19   64
# 20   90
# 21   83
# 22   71
# 23   67
# 24   63
# 25   92
# 26   84
# 27   79
# 28   74
# 29   68

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,df_y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.model_selection import cross_val_score
def model_evaluation(model,df_x,df_y):
    cvs=cross_val_score(model,df_x,df_y,cv=5,scoring="r2")
    print("Mean r2 score : ",cvs.mean())
    print("standard deviation in r2 score for regressor: ",cvs.std())
    print(cvs)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
r_state = maxr2_score(lg,df_x,df_y)
# Out:
# max r2 score corresponding to  73  is  0.8507709590470761

# %%
model_evaluation(lg,df_x,df_y)
# Out:
# Mean r2 score :  0.04078645834644319
# standard deviation in r2 score for regressor:  0.4473773492059681
# [ 0.5578333  -0.36011946  0.61092665 -0.22451215 -0.38019605]

# %% [markdown]
# KNN Model

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
r_state = maxr2_score(knn,df_x,df_y)
# Out:
# max r2 score corresponding to  46  is  0.7544084056646871

# %%
model_evaluation(knn,df_x,df_y)
# Out:
# Mean r2 score :  -0.3713747420468805
# standard deviation in r2 score for regressor:  1.2193401002046482
# [-0.65572727 -2.62052632  0.37716437  0.25554098  0.78667453]

# %% [markdown]
# Grid Search for KNN Model

# %%
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,25)}
knr=KNeighborsRegressor()
clf = GridSearchCV(knr, neighbors, cv=10)
clf.fit(df_x,df_y)
clf.best_params_
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'n_neighbors': 3}

# %%
knr=KNeighborsRegressor(n_neighbors=3)
r_state=maxr2_score(knr,df_x,df_y)
# Out:
# max r2 score corresponding to  82  is  0.7819977212305353

# %%
model_evaluation(knr,df_x,df_y)
# Out:
# Mean r2 score :  -0.357257326953831
# standard deviation in r2 score for regressor:  0.7953506498451224
# [-1.25871212 -1.36549708  0.30006041  0.02659381  0.51126834]

# %% [markdown]
# Boosting KNN Model

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_knn=AdaBoostRegressor()
ada_knn=AdaBoostRegressor(base_estimator=knn,learning_rate=0.1,n_estimators=10)

# %%
r_state=maxr2_score(ada_knn,df_x,df_y)
# Out:
# max r2 score corresponding to  99  is  0.7658994901675162

# %%
model_evaluation(ada_knn,df_x,df_y)
# Out:
# Mean r2 score :  -0.2859998741720002
# standard deviation in r2 score for regressor:  1.0199925493048907
# [-0.97522727 -1.91368421  0.34089502  0.20091803  0.91709906]

# %%
#SVM Regressor
from sklearn.svm import SVR
sv = SVR(kernel = "linear")
r_state=maxr2_score(sv,df_x,df_y)
# Out:
# max r2 score corresponding to  54  is  0.8243696620359938

# %%
model_evaluation(sv,df_x,df_y)
# Out:
# Mean r2 score :  -1.337798473780779
# standard deviation in r2 score for regressor:  1.6067998765661273
# [-1.02839204 -3.97414087  0.25168876  0.2687891  -2.20693732]

# %% [markdown]
# Grid Search CV for SVR Model

# %%
parameters = {'kernel': ('linear', 'rbf','poly'), 'C':[1.5, 10],'gamma': [1e-7, 1e-4],'epsilon':[0.1,0.2,0.5,0.3]}
svr = SVR()
grs = GridSearchCV(svr, parameters,refit = True, verbose = 3)
grs.fit(df_x,df_y)
grs.best_params_
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear, score=-1.468, total=   0.1s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear ..................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear, score=-0.308, total=   0.1s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear ..................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=linear, score=-12.161, total=   0.1s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf .....................
# [CV]  C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf, score=-0.307, total=   0.0s
# [CV] C=1.5, epsilon=0.1, gamma=1e-07, kernel=rbf .....................
# ...

# %%
svr_gs=SVR(C=10, epsilon=0.1, gamma=1e-07, kernel='poly')
model_evaluation(svr_gs,df_x,df_y)
# Out:
# Mean r2 score :  -0.15500712115370702
# standard deviation in r2 score for regressor:  0.8416436205794902
# [-0.1532057  -1.72863609  0.37766174  0.01683163  0.71231282]

# %% [markdown]
# RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
r_state=maxr2_score(rf,df_x,df_y)
# Out:
# max r2 score corresponding to  99  is  0.8239111434814277

# %%
model_evaluation(rf,df_x,df_y)
# Out:
# Mean r2 score :  -0.9390239351066576
# standard deviation in r2 score for regressor:  2.5904764239517815
# [-0.32484091 -6.0525      0.62134672  0.15990164  0.90097288]

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
r_state=maxr2_score(dt,df_x,df_y)
# Out:
# max r2 score corresponding to  81  is  0.8529688972667295

# %%
model_evaluation(dt,df_x,df_y)
# Out:
# Mean r2 score :  -2.3577585455361203
# standard deviation in r2 score for regressor:  3.742028575042604
# [-3.28181818 -9.31578947  0.300711    0.12131148  0.38679245]

# %%
parameters = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }


dt_gs = GridSearchCV(dt, parameters, cv=5)
dt_gs.fit(df_x,df_y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
# ...

# %%
dt_gs.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 2,
#  'max_leaf_nodes': 5,
#  'min_samples_leaf': 20,
#  'min_samples_split': 10}

# %%
dt_gs.best_score_
# Out:
# -0.400906006432155

# %%
dtrg=DecisionTreeRegressor(criterion= 'mse',
 max_depth= 2,
 max_leaf_nodes=5,
 min_samples_leaf= 20,
 min_samples_split= 10)
dtrg.fit(df_x,df_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,
#                       max_leaf_nodes=5, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=20,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
# Selecting Linear Regression Model as final , since it has highest R2 score 0.85
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y,random_state =73,test_size=0.20)
lg_final=LinearRegression()
lg_final.fit(x_train,y_train)
y_pred=lg_final.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  4.453653185119619
# r2_score is:  0.8507709590470761

# %%
#Lets save the above model
from sklearn.externals import joblib

#Save the model as pickle in a file
joblib.dump(lg_final,'Model_Baseball.pkl')
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['Model_Baseball.pkl']
